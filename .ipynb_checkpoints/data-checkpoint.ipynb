# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
result_csv = 'build/data.csv'

df = pd.read_csv(result_csv)
display(df)
# Out:
#      n  algorithm    time
# 0    1          0  36835.7
# 1    1          1  37181.7
# 2    1          2  37190.6
# 3    3          0  37999.1
# 4    3          1  37991.7
# ..  ..        ...      ...
# 67  45          1  43683.5
# 68  45          2  43700.4
# 69  47          0  44037.4
# 70  47          1  44065.8
# 71  47          2  43786.7
#
# [72 rows x 3 columns]

# %%
rect_df = df[df.algorithm == 0]
tri_df = df[df.algorithm == 1]
gau_df = df[df.algorithm == 2]

# %%
display(rect_df)

print(rect_df.columns)

x = rect_df["n"].to_numpy()
rect_time = rect_df["time "].to_numpy()
tri_time = tri_df["time "].to_numpy()
gauss_time = gau_df["time "].to_numpy()
# Out:
#      n  algorithm    time
# 0    1          0  36835.7
# 3    3          0  37999.1
# 6    5          0  38960.1
# 9    7          0  39414.0
# 12   9          0  40405.7
# 15  11          0  40686.2
# 18  13          0  40639.3
# 21  15          0  40873.2
# 24  17          0  41510.9
# 27  19          0  41676.3
# 30  21          0  41917.0
# 33  23          0  42006.8
# 36  25          0  42057.0
# 39  27          0  42619.4
# 42  29          0  42426.0
# 45  31          0  42574.6
# 48  33          0  42926.4
# 51  35          0  43037.1
# 54  37          0  43495.3
# 57  39          0  43322.3
# 60  41          0  43751.3
# 63  43          0  44000.3
# 66  45          0  44015.4
# 69  47          0  44037.4
# Index(['n', 'algorithm', 'time '], dtype='object')

# %%
plt.figure(figsize=(20, 10))
plt.plot(x, rect_time, label='rectangular')
plt.plot(x, tri_time, label='triangular')
plt.plot(x, gauss_time, label='gaussian')
plt.xlabel('n')
plt.ylabel('time(ms)')

plt.legend()
plt.show()

# %%
# make videos
import os
from os.path import join
from tqdm import tqdm

def get_files(folder):
    return [join(folder, f) for f in os.listdir(folder) if os.path.isfile(join(folder,f))]

folder = 'build/video_out'
files = get_files(folder)
prefix_set = set()
for f in tqdm(files):
    prefix = f[:f.find('.png')-5]
    prefix_set.add(prefix)

os.makedirs("video_out", exist_ok=True)

for prefix in tqdm(prefix_set):
    base_prefix = os.path.basename(prefix)
    outname =  join("video_out", base_prefix + '.mp4')
    cmd = 'ffmpeg -r 12 -f image2 -s 1920x1080 -i {}_%04d.png -vcodec libx264 -crf 25  -pix_fmt yuv420p {}'.format(prefix, outname)
    os.system(cmd)
# Out:
# ...
#   0%|          | 0/73 [00:00<?, ?it/s]
# ffmpeg -r 12 -f image2 -s 1920x1080 -i build/video_out/41_1_%04d.png -vcodec libx264 -crf 25  -pix_fmt yuv420p video_out/41_1.gif
#   0%|          | 0/73 [00:00<?, ?it/s]
